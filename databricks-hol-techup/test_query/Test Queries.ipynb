-- %%
DECLARE OR REPLACE VARIABLE myusername STRING; 
SET VAR myusername = (select concat( 'test', replace(replace(current_user(),'@',''),'.','')));

-- %%
USE catalog apjtechup;
create database if not exists IDENTIFIER(myusername);
use database IDENTIFIER(myusername);

-- %%
create or replace table IDENTIFIER(myusername) as select * from apjtechup.bronze.categories_raw limit 10

-- %%
select * from IDENTIFIER(myusername)

-- %%
drop table IDENTIFIER(myusername)

-- %%
drop database IDENTIFIER(myusername)
